# %%
# %%sql
#
# -----------------------------
# -- Create SCHEMAS --
# -----------------------------
#
# CREATE SCHEMA Bronze;
# CREATE SCHEMA Silver;
# CREATE SCHEMA Gold;
# Out:
# StatementMeta(, 336fe9d1-777f-4b69-8762-376cc20da405, 6, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
